# %% [markdown]
# Masalah ini biasanya karena drive dalam keadaan dirty (tidak dilepas dengan benar/safety remove) atau terkunci karena fast startup windows

# %% [markdown]
# cara paling mudahnya mounting manual
#
#
# 1. buat direktori
# sudo mkdir -p /mnt/ssd
#
# 2. mount ssd
# sudo mount /dev/sda1 /mnt/ssd
